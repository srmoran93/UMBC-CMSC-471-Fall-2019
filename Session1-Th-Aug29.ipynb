# %% [markdown]
# #### <h1><center>CMSC 471: Introduction to Artificial Intelligence</center></h1>
#
# <center><img src="img/title.jpeg" align="center"/></center>
#
#
# <h3 style="color:blue;"><center>Instructor: Fereydoon "Fred" Vafaei</center></h3>
#
#
# <h5 style="color:purple;"><center>Session 1: August 29, 2019 - Introduction and Syllabus</center></h5>
#
# <center><img src="img/UMBC_logo.png" align="center"/></center>

# %% [markdown]
# <h1><center>Agenda</center></h1>
#
# - <b>Introduction</b> Who is the instructor? Who are the students? What is this class about?
# - <b>Syllabus:</b> Course description, learning objectives, grading policy, etc.
# - <b>Assignment 0 and quiz 0:</b> **Come on Fereydoon!!**

# %% [markdown]
# <h1><center>About Fereydoon</center></h1>
#
# <img src="img/Elliott-Fereydoon-EEG.jpg" align="left"/>
# <img src="img/EEG-NDSU.jpg" align="right"/>
# <img src="img/umbc.jpg" align="right"/>

# %%
# Fereydoon's research: applications of Deep Learning on fMRI analysis - sample Python script
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
anat_img = nib.load('wm20120615_111443fMRIImitation3s003a1001.nii')
anat_img_data = anat_img.get_data()
def show_slices(slices):
    """ Function to display row of image slices """
    fig, axes = plt.subplots(1, len(slices))
    for i, slice in enumerate(slices):
        axes[i].imshow(slice.T, cmap="gray", origin="lower")
show_slices([anat_img_data[35, :, :],
             anat_img_data[:, 33, :],
             anat_img_data[:, :, 38]])
print(type(anat_img_data))
plt.suptitle("Center slices for anatomical image")
# Out:
# <class 'numpy.memmap'>
# Text(0.5, 0.98, 'Center slices for anatomical image')

# %% [markdown]
# <h1><center>What is Artificial Intelligence?</center></h1>
#
# <center><img src="img/AI-ML-DL.jpeg" align="center"/></center>

# %% [markdown]
# <h1><center>Syllabus</center></h1>
#
# - <b>Course description and learning goals</b>
# - <b>Textbook</b> [Artificial Intelligence - A Modern Approach - 3rd Edition, By: Russel and Norvig](http://www.mypearsonstore.com/bookstore/artificial-intelligence-a-modern-approach-9780136042594?xid=PSED)
#
# - <b>Grading policy</b> Attendance and participation 5%, Quiz and reading assignments 15%, homework and programming assignments 40%, project 20%, two eams 20%
# - <b>Late policy</b> Penalty for 1-minute-late submission: 25%, and so forth, zero credit for late submissions after 72 hours!
# - <b>Discussion Board:</b> [Piazza](https://piazza.com/class/jzuiol1lsh349o)
# - <b>Academic integrity</b>

# %% [markdown]
# <h1><center>Assignment 0 and Quiz 0! Really?!</center></h1>
